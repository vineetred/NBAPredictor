# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers import Dropout,Conv2D
from sklearn.model_selection import train_test_split
import csv
import pandas as pd
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()
main = pd.read_csv('dataset/nba.games.stats - nba_2018.csv')
home = pd.read_csv('dataset/nba.games.stats - nba_prev.csv',usecols=['Team'])
away = pd.read_csv('dataset/nba.games.stats - nba_prev.csv',usecols=['Opponent']).values
ha = pd.read_csv('dataset/nba.games.stats - nba_prev.csv',usecols=['Home']).values

home = encoder.fit_transform(home)
away = encoder.fit_transform(away)
homeaway = encoder.fit_transform(ha)

new = np.append(home,away,axis=1)
# new2 = pd.read_csv('dataset/nba.games.stats - nba_prev.csv',usecols=['FieldGoals','FieldGoalsAttempted','FieldGoals.','X3PointShots','X3PointShotsAttempted','X3PointShots.','FreeThrows','FreeThrowsAttempted','FreeThrows.','OffRebounds','TotalRebounds','Assists','Steals','Blocks','Turnovers','TotalFouls',
#                         'Opp.FieldGoals', 'Opp.3PointShotsAttempted', 'Opp.3PointShots.', 'Opp.FreeThrows', 
#                         'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds', 
#                         'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers', 'Opp.TotalFouls',
#                         'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.', 'Opp.3PointShots']).values

features = ['FieldGoalsAttempted','FreeThrows','FreeThrowsAttempted','FreeThrows.','OffRebounds','TotalRebounds','Assists','Steals','Blocks','Turnovers','TotalFouls',
                        'Opp.FreeThrows', 
                        'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds', 
                        'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers', 'Opp.TotalFouls',
                        'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.', 'Opp.3PointShots']




def NN():
    new2 = pd.read_csv('dataset/nba.games.stats - nba_prev.csv',usecols=['FieldGoalsAttempted','FreeThrows','FreeThrowsAttempted','FreeThrows.','OffRebounds','TotalRebounds','Assists','Steals','Blocks','Turnovers','TotalFouls',
                            'Opp.FreeThrows', 
                            'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds', 
                            'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers', 'Opp.TotalFouls',
                            'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.', 'Opp.3PointShots']).values


    new3 = np.append(new,homeaway,axis=1)
    new2 = np.append(new3,new2,axis=1)
    winLoss =  pd.read_csv('dataset/nba.games.stats - nba_prev.csv',usecols=['WINorLOSS']).values
    winLoss = encoder.fit_transform(winLoss)
    points = pd.read_csv('dataset/nba.games.stats - nba_prev.csv',usecols=['TeamPoints','OpponentPoints']).values
    points = np.append(points,winLoss,axis=1)
    # points.shape
    # points = winLoss
    X_train, X_test, y_train, y_test = train_test_split(new2, winLoss, test_size=0.0001)

    #MODEL
    model = Sequential()
    keras.optimizers.adam(lr=0.1)
    model.add(Dense(30, activation='relu',input_dim=85))
    model.add(Dropout(0.30))
    # model.add(Dense(46, activation='relu'))
    # model.add(Dense(30, activation='sigmoid'))
    model.add(Dense(25, activation='relu'))
    model.add(Dense(10, activation='relu'))

    # model.add(Dense(20, activation='relu'))
    model.add(Dense(1, activation = 'sigmoid'))

    model.compile(loss='mean_squared_error',
                  optimizer='adam',
                  metrics=['accuracy'])

    history = model.fit(np.asarray(X_train),np.asarray(y_train), epochs=40)
    print(model.evaluate(X_test,y_test))

predict = np.asarray([new2[674]])

# %%
import itertools
for i in range(1,len(features)):
    for x in (itertools.combinations(features,i)):
        print(x)
# Out:
# ('FieldGoalsAttempted',)
# ('FreeThrows',)
# ('FreeThrowsAttempted',)
# ('FreeThrows.',)
# ('OffRebounds',)
# ('TotalRebounds',)
# ('Assists',)
# ('Steals',)
# ('Blocks',)
# ('Turnovers',)
# ('TotalFouls',)
# ('Opp.FreeThrows',)
# ('Opp.FreeThrowsAttempted',)
# ('Opp.FreeThrows.',)
# ('Opp.OffRebounds',)
# ('Opp.TotalRebounds',)
# ('Opp.Assists',)
# ('Opp.Steals',)
# ('Opp.Blocks',)
# ('Opp.Turnovers',)
# ('Opp.TotalFouls',)
# ('Opp.FieldGoalsAttempted',)
# ('Opp.FieldGoals.',)
# ('Opp.3PointShots',)
# ('FieldGoalsAttempted', 'FreeThrows')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'FreeThrows.')
# ('FieldGoalsAttempted', 'OffRebounds')
# ('FieldGoalsAttempted', 'TotalRebounds')
# ('FieldGoalsAttempted', 'Assists')
# ('FieldGoalsAttempted', 'Steals')
# ('FieldGoalsAttempted', 'Blocks')
# ('FieldGoalsAttempted', 'Turnovers')
# ('FieldGoalsAttempted', 'TotalFouls')
# ('FieldGoalsAttempted', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.3PointShots')
# ('FreeThrows', 'FreeThrowsAttempted')
# ('FreeThrows', 'FreeThrows.')
# ('FreeThrows', 'OffRebounds')
# ('FreeThrows', 'TotalRebounds')
# ('FreeThrows', 'Assists')
# ('FreeThrows', 'Steals')
# ('FreeThrows', 'Blocks')
# ('FreeThrows', 'Turnovers')
# ('FreeThrows', 'TotalFouls')
# ('FreeThrows', 'Opp.FreeThrows')
# ('FreeThrows', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'Opp.FreeThrows.')
# ('FreeThrows', 'Opp.OffRebounds')
# ('FreeThrows', 'Opp.TotalRebounds')
# ('FreeThrows', 'Opp.Assists')
# ('FreeThrows', 'Opp.Steals')
# ('FreeThrows', 'Opp.Blocks')
# ('FreeThrows', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'FreeThrows.')
# ('FreeThrowsAttempted', 'OffRebounds')
# ('FreeThrowsAttempted', 'TotalRebounds')
# ('FreeThrowsAttempted', 'Assists')
# ('FreeThrowsAttempted', 'Steals')
# ('FreeThrowsAttempted', 'Blocks')
# ('FreeThrowsAttempted', 'Turnovers')
# ('FreeThrowsAttempted', 'TotalFouls')
# ('FreeThrowsAttempted', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.3PointShots')
# ('FreeThrows.', 'OffRebounds')
# ('FreeThrows.', 'TotalRebounds')
# ('FreeThrows.', 'Assists')
# ('FreeThrows.', 'Steals')
# ('FreeThrows.', 'Blocks')
# ('FreeThrows.', 'Turnovers')
# ('FreeThrows.', 'TotalFouls')
# ('FreeThrows.', 'Opp.FreeThrows')
# ('FreeThrows.', 'Opp.FreeThrowsAttempted')
# ('FreeThrows.', 'Opp.FreeThrows.')
# ('FreeThrows.', 'Opp.OffRebounds')
# ('FreeThrows.', 'Opp.TotalRebounds')
# ('FreeThrows.', 'Opp.Assists')
# ('FreeThrows.', 'Opp.Steals')
# ('FreeThrows.', 'Opp.Blocks')
# ('FreeThrows.', 'Opp.Turnovers')
# ('FreeThrows.', 'Opp.TotalFouls')
# ('FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'Opp.FieldGoals.')
# ('FreeThrows.', 'Opp.3PointShots')
# ('OffRebounds', 'TotalRebounds')
# ('OffRebounds', 'Assists')
# ('OffRebounds', 'Steals')
# ('OffRebounds', 'Blocks')
# ('OffRebounds', 'Turnovers')
# ('OffRebounds', 'TotalFouls')
# ('OffRebounds', 'Opp.FreeThrows')
# ('OffRebounds', 'Opp.FreeThrowsAttempted')
# ('OffRebounds', 'Opp.FreeThrows.')
# ('OffRebounds', 'Opp.OffRebounds')
# ('OffRebounds', 'Opp.TotalRebounds')
# ('OffRebounds', 'Opp.Assists')
# ('OffRebounds', 'Opp.Steals')
# ('OffRebounds', 'Opp.Blocks')
# ('OffRebounds', 'Opp.Turnovers')
# ('OffRebounds', 'Opp.TotalFouls')
# ('OffRebounds', 'Opp.FieldGoalsAttempted')
# ('OffRebounds', 'Opp.FieldGoals.')
# ('OffRebounds', 'Opp.3PointShots')
# ('TotalRebounds', 'Assists')
# ('TotalRebounds', 'Steals')
# ('TotalRebounds', 'Blocks')
# ('TotalRebounds', 'Turnovers')
# ('TotalRebounds', 'TotalFouls')
# ('TotalRebounds', 'Opp.FreeThrows')
# ('TotalRebounds', 'Opp.FreeThrowsAttempted')
# ('TotalRebounds', 'Opp.FreeThrows.')
# ('TotalRebounds', 'Opp.OffRebounds')
# ('TotalRebounds', 'Opp.TotalRebounds')
# ('TotalRebounds', 'Opp.Assists')
# ('TotalRebounds', 'Opp.Steals')
# ('TotalRebounds', 'Opp.Blocks')
# ('TotalRebounds', 'Opp.Turnovers')
# ('TotalRebounds', 'Opp.TotalFouls')
# ('TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('TotalRebounds', 'Opp.FieldGoals.')
# ('TotalRebounds', 'Opp.3PointShots')
# ('Assists', 'Steals')
# ('Assists', 'Blocks')
# ('Assists', 'Turnovers')
# ('Assists', 'TotalFouls')
# ('Assists', 'Opp.FreeThrows')
# ('Assists', 'Opp.FreeThrowsAttempted')
# ('Assists', 'Opp.FreeThrows.')
# ('Assists', 'Opp.OffRebounds')
# ('Assists', 'Opp.TotalRebounds')
# ('Assists', 'Opp.Assists')
# ('Assists', 'Opp.Steals')
# ('Assists', 'Opp.Blocks')
# ('Assists', 'Opp.Turnovers')
# ('Assists', 'Opp.TotalFouls')
# ('Assists', 'Opp.FieldGoalsAttempted')
# ('Assists', 'Opp.FieldGoals.')
# ('Assists', 'Opp.3PointShots')
# ('Steals', 'Blocks')
# ('Steals', 'Turnovers')
# ('Steals', 'TotalFouls')
# ('Steals', 'Opp.FreeThrows')
# ('Steals', 'Opp.FreeThrowsAttempted')
# ('Steals', 'Opp.FreeThrows.')
# ('Steals', 'Opp.OffRebounds')
# ('Steals', 'Opp.TotalRebounds')
# ('Steals', 'Opp.Assists')
# ('Steals', 'Opp.Steals')
# ('Steals', 'Opp.Blocks')
# ('Steals', 'Opp.Turnovers')
# ('Steals', 'Opp.TotalFouls')
# ('Steals', 'Opp.FieldGoalsAttempted')
# ('Steals', 'Opp.FieldGoals.')
# ('Steals', 'Opp.3PointShots')
# ('Blocks', 'Turnovers')
# ('Blocks', 'TotalFouls')
# ('Blocks', 'Opp.FreeThrows')
# ('Blocks', 'Opp.FreeThrowsAttempted')
# ('Blocks', 'Opp.FreeThrows.')
# ('Blocks', 'Opp.OffRebounds')
# ('Blocks', 'Opp.TotalRebounds')
# ('Blocks', 'Opp.Assists')
# ('Blocks', 'Opp.Steals')
# ('Blocks', 'Opp.Blocks')
# ('Blocks', 'Opp.Turnovers')
# ('Blocks', 'Opp.TotalFouls')
# ('Blocks', 'Opp.FieldGoalsAttempted')
# ('Blocks', 'Opp.FieldGoals.')
# ('Blocks', 'Opp.3PointShots')
# ('Turnovers', 'TotalFouls')
# ('Turnovers', 'Opp.FreeThrows')
# ('Turnovers', 'Opp.FreeThrowsAttempted')
# ('Turnovers', 'Opp.FreeThrows.')
# ('Turnovers', 'Opp.OffRebounds')
# ('Turnovers', 'Opp.TotalRebounds')
# ('Turnovers', 'Opp.Assists')
# ('Turnovers', 'Opp.Steals')
# ('Turnovers', 'Opp.Blocks')
# ('Turnovers', 'Opp.Turnovers')
# ('Turnovers', 'Opp.TotalFouls')
# ('Turnovers', 'Opp.FieldGoalsAttempted')
# ('Turnovers', 'Opp.FieldGoals.')
# ('Turnovers', 'Opp.3PointShots')
# ('TotalFouls', 'Opp.FreeThrows')
# ('TotalFouls', 'Opp.FreeThrowsAttempted')
# ('TotalFouls', 'Opp.FreeThrows.')
# ('TotalFouls', 'Opp.OffRebounds')
# ('TotalFouls', 'Opp.TotalRebounds')
# ('TotalFouls', 'Opp.Assists')
# ('TotalFouls', 'Opp.Steals')
# ('TotalFouls', 'Opp.Blocks')
# ('TotalFouls', 'Opp.Turnovers')
# ('TotalFouls', 'Opp.TotalFouls')
# ('TotalFouls', 'Opp.FieldGoalsAttempted')
# ('TotalFouls', 'Opp.FieldGoals.')
# ('TotalFouls', 'Opp.3PointShots')
# ('Opp.FreeThrows', 'Opp.FreeThrowsAttempted')
# ('Opp.FreeThrows', 'Opp.FreeThrows.')
# ('Opp.FreeThrows', 'Opp.OffRebounds')
# ('Opp.FreeThrows', 'Opp.TotalRebounds')
# ('Opp.FreeThrows', 'Opp.Assists')
# ('Opp.FreeThrows', 'Opp.Steals')
# ('Opp.FreeThrows', 'Opp.Blocks')
# ('Opp.FreeThrows', 'Opp.Turnovers')
# ('Opp.FreeThrows', 'Opp.TotalFouls')
# ('Opp.FreeThrows', 'Opp.FieldGoalsAttempted')
# ('Opp.FreeThrows', 'Opp.FieldGoals.')
# ('Opp.FreeThrows', 'Opp.3PointShots')
# ('Opp.FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('Opp.FreeThrowsAttempted', 'Opp.OffRebounds')
# ('Opp.FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('Opp.FreeThrowsAttempted', 'Opp.Assists')
# ('Opp.FreeThrowsAttempted', 'Opp.Steals')
# ('Opp.FreeThrowsAttempted', 'Opp.Blocks')
# ('Opp.FreeThrowsAttempted', 'Opp.Turnovers')
# ('Opp.FreeThrowsAttempted', 'Opp.TotalFouls')
# ('Opp.FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('Opp.FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('Opp.FreeThrowsAttempted', 'Opp.3PointShots')
# ('Opp.FreeThrows.', 'Opp.OffRebounds')
# ('Opp.FreeThrows.', 'Opp.TotalRebounds')
# ('Opp.FreeThrows.', 'Opp.Assists')
# ('Opp.FreeThrows.', 'Opp.Steals')
# ('Opp.FreeThrows.', 'Opp.Blocks')
# ('Opp.FreeThrows.', 'Opp.Turnovers')
# ('Opp.FreeThrows.', 'Opp.TotalFouls')
# ('Opp.FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('Opp.FreeThrows.', 'Opp.FieldGoals.')
# ('Opp.FreeThrows.', 'Opp.3PointShots')
# ('Opp.OffRebounds', 'Opp.TotalRebounds')
# ('Opp.OffRebounds', 'Opp.Assists')
# ('Opp.OffRebounds', 'Opp.Steals')
# ('Opp.OffRebounds', 'Opp.Blocks')
# ('Opp.OffRebounds', 'Opp.Turnovers')
# ('Opp.OffRebounds', 'Opp.TotalFouls')
# ('Opp.OffRebounds', 'Opp.FieldGoalsAttempted')
# ('Opp.OffRebounds', 'Opp.FieldGoals.')
# ('Opp.OffRebounds', 'Opp.3PointShots')
# ('Opp.TotalRebounds', 'Opp.Assists')
# ('Opp.TotalRebounds', 'Opp.Steals')
# ('Opp.TotalRebounds', 'Opp.Blocks')
# ('Opp.TotalRebounds', 'Opp.Turnovers')
# ('Opp.TotalRebounds', 'Opp.TotalFouls')
# ('Opp.TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('Opp.TotalRebounds', 'Opp.FieldGoals.')
# ('Opp.TotalRebounds', 'Opp.3PointShots')
# ('Opp.Assists', 'Opp.Steals')
# ('Opp.Assists', 'Opp.Blocks')
# ('Opp.Assists', 'Opp.Turnovers')
# ('Opp.Assists', 'Opp.TotalFouls')
# ('Opp.Assists', 'Opp.FieldGoalsAttempted')
# ('Opp.Assists', 'Opp.FieldGoals.')
# ('Opp.Assists', 'Opp.3PointShots')
# ('Opp.Steals', 'Opp.Blocks')
# ('Opp.Steals', 'Opp.Turnovers')
# ('Opp.Steals', 'Opp.TotalFouls')
# ('Opp.Steals', 'Opp.FieldGoalsAttempted')
# ('Opp.Steals', 'Opp.FieldGoals.')
# ('Opp.Steals', 'Opp.3PointShots')
# ('Opp.Blocks', 'Opp.Turnovers')
# ('Opp.Blocks', 'Opp.TotalFouls')
# ('Opp.Blocks', 'Opp.FieldGoalsAttempted')
# ('Opp.Blocks', 'Opp.FieldGoals.')
# ('Opp.Blocks', 'Opp.3PointShots')
# ('Opp.Turnovers', 'Opp.TotalFouls')
# ('Opp.Turnovers', 'Opp.FieldGoalsAttempted')
# ('Opp.Turnovers', 'Opp.FieldGoals.')
# ('Opp.Turnovers', 'Opp.3PointShots')
# ('Opp.TotalFouls', 'Opp.FieldGoalsAttempted')
# ('Opp.TotalFouls', 'Opp.FieldGoals.')
# ('Opp.TotalFouls', 'Opp.3PointShots')
# ('Opp.FieldGoalsAttempted', 'Opp.FieldGoals.')
# ('Opp.FieldGoalsAttempted', 'Opp.3PointShots')
# ('Opp.FieldGoals.', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'FreeThrows', 'FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'FreeThrows', 'FreeThrows.')
# ('FieldGoalsAttempted', 'FreeThrows', 'OffRebounds')
# ('FieldGoalsAttempted', 'FreeThrows', 'TotalRebounds')
# ('FieldGoalsAttempted', 'FreeThrows', 'Assists')
# ('FieldGoalsAttempted', 'FreeThrows', 'Steals')
# ('FieldGoalsAttempted', 'FreeThrows', 'Blocks')
# ('FieldGoalsAttempted', 'FreeThrows', 'Turnovers')
# ('FieldGoalsAttempted', 'FreeThrows', 'TotalFouls')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.Assists')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.Steals')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'FreeThrows', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'FreeThrows.')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'OffRebounds')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'TotalRebounds')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Assists')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Steals')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Blocks')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Turnovers')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'TotalFouls')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.Assists')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.Steals')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'FreeThrowsAttempted', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'FreeThrows.', 'OffRebounds')
# ('FieldGoalsAttempted', 'FreeThrows.', 'TotalRebounds')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Assists')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Steals')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Blocks')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Turnovers')
# ('FieldGoalsAttempted', 'FreeThrows.', 'TotalFouls')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.Assists')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.Steals')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'FreeThrows.', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'OffRebounds', 'TotalRebounds')
# ('FieldGoalsAttempted', 'OffRebounds', 'Assists')
# ('FieldGoalsAttempted', 'OffRebounds', 'Steals')
# ('FieldGoalsAttempted', 'OffRebounds', 'Blocks')
# ('FieldGoalsAttempted', 'OffRebounds', 'Turnovers')
# ('FieldGoalsAttempted', 'OffRebounds', 'TotalFouls')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.Assists')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.Steals')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'OffRebounds', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Assists')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Steals')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Blocks')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Turnovers')
# ('FieldGoalsAttempted', 'TotalRebounds', 'TotalFouls')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.Assists')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.Steals')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'TotalRebounds', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Assists', 'Steals')
# ('FieldGoalsAttempted', 'Assists', 'Blocks')
# ('FieldGoalsAttempted', 'Assists', 'Turnovers')
# ('FieldGoalsAttempted', 'Assists', 'TotalFouls')
# ('FieldGoalsAttempted', 'Assists', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'Assists', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'Assists', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'Assists', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Assists', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Assists', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Assists', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Assists', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Assists', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Assists', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Assists', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Assists', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Assists', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Steals', 'Blocks')
# ('FieldGoalsAttempted', 'Steals', 'Turnovers')
# ('FieldGoalsAttempted', 'Steals', 'TotalFouls')
# ('FieldGoalsAttempted', 'Steals', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'Steals', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'Steals', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'Steals', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Steals', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Steals', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Steals', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Steals', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Steals', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Steals', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Steals', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Steals', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Steals', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Blocks', 'Turnovers')
# ('FieldGoalsAttempted', 'Blocks', 'TotalFouls')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Blocks', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Turnovers', 'TotalFouls')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Turnovers', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.FreeThrows')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.Assists')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.Steals')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'TotalFouls', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.FreeThrows', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.FreeThrows.', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.TotalRebounds')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.OffRebounds', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.Assists')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.TotalRebounds', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.Assists', 'Opp.Steals')
# ('FieldGoalsAttempted', 'Opp.Assists', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.Assists', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.Assists', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.Assists', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.Assists', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.Assists', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.Steals', 'Opp.Blocks')
# ('FieldGoalsAttempted', 'Opp.Steals', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.Steals', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.Steals', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.Steals', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.Steals', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.Blocks', 'Opp.Turnovers')
# ('FieldGoalsAttempted', 'Opp.Blocks', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.Blocks', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.Blocks', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.Blocks', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.Turnovers', 'Opp.TotalFouls')
# ('FieldGoalsAttempted', 'Opp.Turnovers', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.Turnovers', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.Turnovers', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FieldGoalsAttempted', 'Opp.TotalFouls', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.TotalFouls', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.')
# ('FieldGoalsAttempted', 'Opp.FieldGoalsAttempted', 'Opp.3PointShots')
# ('FieldGoalsAttempted', 'Opp.FieldGoals.', 'Opp.3PointShots')
# ('FreeThrows', 'FreeThrowsAttempted', 'FreeThrows.')
# ('FreeThrows', 'FreeThrowsAttempted', 'OffRebounds')
# ('FreeThrows', 'FreeThrowsAttempted', 'TotalRebounds')
# ('FreeThrows', 'FreeThrowsAttempted', 'Assists')
# ('FreeThrows', 'FreeThrowsAttempted', 'Steals')
# ('FreeThrows', 'FreeThrowsAttempted', 'Blocks')
# ('FreeThrows', 'FreeThrowsAttempted', 'Turnovers')
# ('FreeThrows', 'FreeThrowsAttempted', 'TotalFouls')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.FreeThrows')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.Assists')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.Steals')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.Blocks')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.Turnovers')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FreeThrows', 'FreeThrowsAttempted', 'Opp.3PointShots')
# ('FreeThrows', 'FreeThrows.', 'OffRebounds')
# ('FreeThrows', 'FreeThrows.', 'TotalRebounds')
# ('FreeThrows', 'FreeThrows.', 'Assists')
# ('FreeThrows', 'FreeThrows.', 'Steals')
# ('FreeThrows', 'FreeThrows.', 'Blocks')
# ('FreeThrows', 'FreeThrows.', 'Turnovers')
# ('FreeThrows', 'FreeThrows.', 'TotalFouls')
# ('FreeThrows', 'FreeThrows.', 'Opp.FreeThrows')
# ('FreeThrows', 'FreeThrows.', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'FreeThrows.', 'Opp.FreeThrows.')
# ('FreeThrows', 'FreeThrows.', 'Opp.OffRebounds')
# ('FreeThrows', 'FreeThrows.', 'Opp.TotalRebounds')
# ('FreeThrows', 'FreeThrows.', 'Opp.Assists')
# ('FreeThrows', 'FreeThrows.', 'Opp.Steals')
# ('FreeThrows', 'FreeThrows.', 'Opp.Blocks')
# ('FreeThrows', 'FreeThrows.', 'Opp.Turnovers')
# ('FreeThrows', 'FreeThrows.', 'Opp.TotalFouls')
# ('FreeThrows', 'FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'FreeThrows.', 'Opp.FieldGoals.')
# ('FreeThrows', 'FreeThrows.', 'Opp.3PointShots')
# ('FreeThrows', 'OffRebounds', 'TotalRebounds')
# ('FreeThrows', 'OffRebounds', 'Assists')
# ('FreeThrows', 'OffRebounds', 'Steals')
# ('FreeThrows', 'OffRebounds', 'Blocks')
# ('FreeThrows', 'OffRebounds', 'Turnovers')
# ('FreeThrows', 'OffRebounds', 'TotalFouls')
# ('FreeThrows', 'OffRebounds', 'Opp.FreeThrows')
# ('FreeThrows', 'OffRebounds', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'OffRebounds', 'Opp.FreeThrows.')
# ('FreeThrows', 'OffRebounds', 'Opp.OffRebounds')
# ('FreeThrows', 'OffRebounds', 'Opp.TotalRebounds')
# ('FreeThrows', 'OffRebounds', 'Opp.Assists')
# ('FreeThrows', 'OffRebounds', 'Opp.Steals')
# ('FreeThrows', 'OffRebounds', 'Opp.Blocks')
# ('FreeThrows', 'OffRebounds', 'Opp.Turnovers')
# ('FreeThrows', 'OffRebounds', 'Opp.TotalFouls')
# ('FreeThrows', 'OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'OffRebounds', 'Opp.FieldGoals.')
# ('FreeThrows', 'OffRebounds', 'Opp.3PointShots')
# ('FreeThrows', 'TotalRebounds', 'Assists')
# ('FreeThrows', 'TotalRebounds', 'Steals')
# ('FreeThrows', 'TotalRebounds', 'Blocks')
# ('FreeThrows', 'TotalRebounds', 'Turnovers')
# ('FreeThrows', 'TotalRebounds', 'TotalFouls')
# ('FreeThrows', 'TotalRebounds', 'Opp.FreeThrows')
# ('FreeThrows', 'TotalRebounds', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'TotalRebounds', 'Opp.FreeThrows.')
# ('FreeThrows', 'TotalRebounds', 'Opp.OffRebounds')
# ('FreeThrows', 'TotalRebounds', 'Opp.TotalRebounds')
# ('FreeThrows', 'TotalRebounds', 'Opp.Assists')
# ('FreeThrows', 'TotalRebounds', 'Opp.Steals')
# ('FreeThrows', 'TotalRebounds', 'Opp.Blocks')
# ('FreeThrows', 'TotalRebounds', 'Opp.Turnovers')
# ('FreeThrows', 'TotalRebounds', 'Opp.TotalFouls')
# ('FreeThrows', 'TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'TotalRebounds', 'Opp.FieldGoals.')
# ('FreeThrows', 'TotalRebounds', 'Opp.3PointShots')
# ('FreeThrows', 'Assists', 'Steals')
# ('FreeThrows', 'Assists', 'Blocks')
# ('FreeThrows', 'Assists', 'Turnovers')
# ('FreeThrows', 'Assists', 'TotalFouls')
# ('FreeThrows', 'Assists', 'Opp.FreeThrows')
# ('FreeThrows', 'Assists', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'Assists', 'Opp.FreeThrows.')
# ('FreeThrows', 'Assists', 'Opp.OffRebounds')
# ('FreeThrows', 'Assists', 'Opp.TotalRebounds')
# ('FreeThrows', 'Assists', 'Opp.Assists')
# ('FreeThrows', 'Assists', 'Opp.Steals')
# ('FreeThrows', 'Assists', 'Opp.Blocks')
# ('FreeThrows', 'Assists', 'Opp.Turnovers')
# ('FreeThrows', 'Assists', 'Opp.TotalFouls')
# ('FreeThrows', 'Assists', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Assists', 'Opp.FieldGoals.')
# ('FreeThrows', 'Assists', 'Opp.3PointShots')
# ('FreeThrows', 'Steals', 'Blocks')
# ('FreeThrows', 'Steals', 'Turnovers')
# ('FreeThrows', 'Steals', 'TotalFouls')
# ('FreeThrows', 'Steals', 'Opp.FreeThrows')
# ('FreeThrows', 'Steals', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'Steals', 'Opp.FreeThrows.')
# ('FreeThrows', 'Steals', 'Opp.OffRebounds')
# ('FreeThrows', 'Steals', 'Opp.TotalRebounds')
# ('FreeThrows', 'Steals', 'Opp.Assists')
# ('FreeThrows', 'Steals', 'Opp.Steals')
# ('FreeThrows', 'Steals', 'Opp.Blocks')
# ('FreeThrows', 'Steals', 'Opp.Turnovers')
# ('FreeThrows', 'Steals', 'Opp.TotalFouls')
# ('FreeThrows', 'Steals', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Steals', 'Opp.FieldGoals.')
# ('FreeThrows', 'Steals', 'Opp.3PointShots')
# ('FreeThrows', 'Blocks', 'Turnovers')
# ('FreeThrows', 'Blocks', 'TotalFouls')
# ('FreeThrows', 'Blocks', 'Opp.FreeThrows')
# ('FreeThrows', 'Blocks', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'Blocks', 'Opp.FreeThrows.')
# ('FreeThrows', 'Blocks', 'Opp.OffRebounds')
# ('FreeThrows', 'Blocks', 'Opp.TotalRebounds')
# ('FreeThrows', 'Blocks', 'Opp.Assists')
# ('FreeThrows', 'Blocks', 'Opp.Steals')
# ('FreeThrows', 'Blocks', 'Opp.Blocks')
# ('FreeThrows', 'Blocks', 'Opp.Turnovers')
# ('FreeThrows', 'Blocks', 'Opp.TotalFouls')
# ('FreeThrows', 'Blocks', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Blocks', 'Opp.FieldGoals.')
# ('FreeThrows', 'Blocks', 'Opp.3PointShots')
# ('FreeThrows', 'Turnovers', 'TotalFouls')
# ('FreeThrows', 'Turnovers', 'Opp.FreeThrows')
# ('FreeThrows', 'Turnovers', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'Turnovers', 'Opp.FreeThrows.')
# ('FreeThrows', 'Turnovers', 'Opp.OffRebounds')
# ('FreeThrows', 'Turnovers', 'Opp.TotalRebounds')
# ('FreeThrows', 'Turnovers', 'Opp.Assists')
# ('FreeThrows', 'Turnovers', 'Opp.Steals')
# ('FreeThrows', 'Turnovers', 'Opp.Blocks')
# ('FreeThrows', 'Turnovers', 'Opp.Turnovers')
# ('FreeThrows', 'Turnovers', 'Opp.TotalFouls')
# ('FreeThrows', 'Turnovers', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Turnovers', 'Opp.FieldGoals.')
# ('FreeThrows', 'Turnovers', 'Opp.3PointShots')
# ('FreeThrows', 'TotalFouls', 'Opp.FreeThrows')
# ('FreeThrows', 'TotalFouls', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'TotalFouls', 'Opp.FreeThrows.')
# ('FreeThrows', 'TotalFouls', 'Opp.OffRebounds')
# ('FreeThrows', 'TotalFouls', 'Opp.TotalRebounds')
# ('FreeThrows', 'TotalFouls', 'Opp.Assists')
# ('FreeThrows', 'TotalFouls', 'Opp.Steals')
# ('FreeThrows', 'TotalFouls', 'Opp.Blocks')
# ('FreeThrows', 'TotalFouls', 'Opp.Turnovers')
# ('FreeThrows', 'TotalFouls', 'Opp.TotalFouls')
# ('FreeThrows', 'TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'TotalFouls', 'Opp.FieldGoals.')
# ('FreeThrows', 'TotalFouls', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.FreeThrows.')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.OffRebounds')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.TotalRebounds')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.Assists')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.Steals')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.Blocks')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.FreeThrows', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.Assists')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.Steals')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.Blocks')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.FreeThrowsAttempted', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.OffRebounds')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.TotalRebounds')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.Assists')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.Steals')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.Blocks')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.FreeThrows.', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.TotalRebounds')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.Assists')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.Steals')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.Blocks')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.OffRebounds', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.Assists')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.Steals')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.Blocks')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.TotalRebounds', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.Assists', 'Opp.Steals')
# ('FreeThrows', 'Opp.Assists', 'Opp.Blocks')
# ('FreeThrows', 'Opp.Assists', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.Assists', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.Assists', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.Assists', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.Assists', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.Steals', 'Opp.Blocks')
# ('FreeThrows', 'Opp.Steals', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.Steals', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.Steals', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.Steals', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.Steals', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.Blocks', 'Opp.Turnovers')
# ('FreeThrows', 'Opp.Blocks', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.Blocks', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.Blocks', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.Blocks', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.Turnovers', 'Opp.TotalFouls')
# ('FreeThrows', 'Opp.Turnovers', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.Turnovers', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.Turnovers', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FreeThrows', 'Opp.TotalFouls', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.TotalFouls', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.')
# ('FreeThrows', 'Opp.FieldGoalsAttempted', 'Opp.3PointShots')
# ('FreeThrows', 'Opp.FieldGoals.', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'FreeThrows.', 'OffRebounds')
# ('FreeThrowsAttempted', 'FreeThrows.', 'TotalRebounds')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Assists')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Steals')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Blocks')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Turnovers')
# ('FreeThrowsAttempted', 'FreeThrows.', 'TotalFouls')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.Assists')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.Steals')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'FreeThrows.', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'OffRebounds', 'TotalRebounds')
# ('FreeThrowsAttempted', 'OffRebounds', 'Assists')
# ('FreeThrowsAttempted', 'OffRebounds', 'Steals')
# ('FreeThrowsAttempted', 'OffRebounds', 'Blocks')
# ('FreeThrowsAttempted', 'OffRebounds', 'Turnovers')
# ('FreeThrowsAttempted', 'OffRebounds', 'TotalFouls')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.Assists')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.Steals')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'OffRebounds', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Assists')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Steals')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Blocks')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Turnovers')
# ('FreeThrowsAttempted', 'TotalRebounds', 'TotalFouls')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.Assists')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.Steals')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'TotalRebounds', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Assists', 'Steals')
# ('FreeThrowsAttempted', 'Assists', 'Blocks')
# ('FreeThrowsAttempted', 'Assists', 'Turnovers')
# ('FreeThrowsAttempted', 'Assists', 'TotalFouls')
# ('FreeThrowsAttempted', 'Assists', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'Assists', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'Assists', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'Assists', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Assists', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Assists', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Assists', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Assists', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Assists', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Assists', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Assists', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Assists', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Assists', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Steals', 'Blocks')
# ('FreeThrowsAttempted', 'Steals', 'Turnovers')
# ('FreeThrowsAttempted', 'Steals', 'TotalFouls')
# ('FreeThrowsAttempted', 'Steals', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'Steals', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'Steals', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'Steals', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Steals', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Steals', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Steals', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Steals', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Steals', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Steals', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Steals', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Steals', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Steals', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Blocks', 'Turnovers')
# ('FreeThrowsAttempted', 'Blocks', 'TotalFouls')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Blocks', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Turnovers', 'TotalFouls')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Turnovers', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.FreeThrows')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.Assists')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.Steals')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'TotalFouls', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.FreeThrows', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.FreeThrowsAttempted', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.TotalRebounds')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.OffRebounds', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.Assists')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.TotalRebounds', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.Assists', 'Opp.Steals')
# ('FreeThrowsAttempted', 'Opp.Assists', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.Assists', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.Assists', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.Assists', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.Assists', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.Assists', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.Steals', 'Opp.Blocks')
# ('FreeThrowsAttempted', 'Opp.Steals', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.Steals', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.Steals', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.Steals', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.Steals', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.Blocks', 'Opp.Turnovers')
# ('FreeThrowsAttempted', 'Opp.Blocks', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.Blocks', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.Blocks', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.Blocks', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.Turnovers', 'Opp.TotalFouls')
# ('FreeThrowsAttempted', 'Opp.Turnovers', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.Turnovers', 'Opp.FieldGoals.')
# ('FreeThrowsAttempted', 'Opp.Turnovers', 'Opp.3PointShots')
# ('FreeThrowsAttempted', 'Opp.TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FreeThrowsAttempted', 'Opp.TotalFouls', 'Opp.FieldGoals.')
# ...
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'TotalFouls', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'TotalFouls', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.FreeThrows.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrowsAttempted', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FreeThrows.', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.OffRebounds', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalRebounds', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Assists', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Assists', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Assists', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Assists', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Assists', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Assists', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Assists', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Steals', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Steals', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Steals', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Steals', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Steals', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Steals', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Blocks', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Blocks', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Blocks', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Blocks', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Blocks', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Turnovers', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Turnovers', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Turnovers', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.Turnovers', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalFouls', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.TotalFouls', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FieldGoalsAttempted', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Steals', 'Opp.FieldGoals.', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.FreeThrows')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.FreeThrowsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.FreeThrows.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Turnovers', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.FreeThrows')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.FreeThrowsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.FreeThrows.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'TotalFouls', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.FreeThrows.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrowsAttempted', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.OffRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.FreeThrows.', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.TotalRebounds')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.OffRebounds', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.Assists')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.TotalRebounds', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Assists', 'Opp.Steals')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Assists', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Assists', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Assists', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Assists', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Assists', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Assists', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Steals', 'Opp.Blocks')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Steals', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Steals', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Steals', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Steals', 'Opp.FieldGoals.')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Steals', 'Opp.3PointShots')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Blocks', 'Opp.Turnovers')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Blocks', 'Opp.TotalFouls')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Blocks', 'Opp.FieldGoalsAttempted')
# ('FreeThrows.', 'TotalRebounds', 'Blocks', 'Opp.Blocks', 'Opp.FieldGoals.')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d7b54b8617e0> in <module>
#       2 for i in range(1,len(features)):
#       3     for x in (itertools.combinations(features,i)):
# ----> 4         print(x)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     390                                  copy_threshold=self.copy_threshold)
#     391             data.group = group
# --> 392         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     393
#     394     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
