# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers import Dropout,Conv2D
from sklearn.model_selection import train_test_split
import csv
import pandas as pd
import matplotlib.pyplot as plt


from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()

# %%
home = pd.read_csv('nba.games.stats - nba_prev.csv',usecols=['Team'])
away = pd.read_csv('nba.games.stats - nba_prev.csv',usecols=['Opponent']).values
ha = pd.read_csv('nba.games.stats - nba_prev.csv',usecols=['Home']).values

# %%
home = encoder.fit_transform(home)
away = encoder.fit_transform(away)
homeaway = encoder.fit_transform(ha)

# %%
new = np.append(home,away,axis=1)
new2 = pd.read_csv('nba.games.stats - nba_prev.csv',usecols=['FieldGoals','FieldGoalsAttempted','FieldGoals.','X3PointShots','X3PointShotsAttempted','X3PointShots.','FreeThrows','FreeThrowsAttempted','FreeThrows.','OffRebounds','TotalRebounds','Assists','Steals','Blocks','Turnovers','TotalFouls',
                        'Opp.FieldGoals', 'Opp.3PointShotsAttempted', 'Opp.3PointShots.', 'Opp.FreeThrows', 
                        'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds', 
                        'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers', 'Opp.TotalFouls',
                        'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.', 'Opp.3PointShots']).values




new3 = np.append(new,homeaway,axis=1)
new2 = np.append(new3,new2,axis=1)
winLoss =  pd.read_csv('nba.games.stats - nba_prev.csv',usecols=['WINorLOSS']).values
winLoss = encoder.fit_transform(winLoss)
points = pd.read_csv('nba.games.stats - nba_prev.csv',usecols=['TeamPoints','OpponentPoints']).values
points = np.append(points,winLoss,axis=1)
# points.shape
# points = winLoss
X_train, X_test, y_train, y_test = train_test_split(new2, points, test_size=0.40)

# %%
#MODEL
model = Sequential()
keras.optimizers.adam(lr=0.2)
model.add(Dense(30, activation='relu',input_dim=93))
model.add(Dropout(0.25))
# model.add(Dense(46, activation='relu'))
# model.add(Dense(30, activation='sigmoid'))
model.add(Dense(25, activation='relu'))
model.add(Dense(10, activation='relu'))

# model.add(Dense(20, activation='relu'))
model.add(Dense(3, activation = 'relu'))

model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(np.asarray(X_train),np.asarray(y_train), epochs=80)
model.evaluate(X_test,y_test)
# Out:
# Epoch 1/80
# 4708/4708 [==============================] - 1s 236us/step - loss: 2534.9017 - acc: 0.4807
# Epoch 2/80
# 4708/4708 [==============================] - 0s 68us/step - loss: 200.9927 - acc: 0.5272
# Epoch 3/80
# 4708/4708 [==============================] - 0s 68us/step - loss: 147.5172 - acc: 0.5516
# Epoch 4/80
# 4708/4708 [==============================] - 0s 70us/step - loss: 121.7741 - acc: 0.5605
# Epoch 5/80
# 4708/4708 [==============================] - 0s 69us/step - loss: 92.6827 - acc: 0.6000
# Epoch 6/80
# 4708/4708 [==============================] - 0s 68us/step - loss: 75.7705 - acc: 0.6117
# Epoch 7/80
# 4708/4708 [==============================] - 0s 68us/step - loss: 60.1277 - acc: 0.6500
# Epoch 8/80
# 4708/4708 [==============================] - 0s 68us/step - loss: 52.4524 - acc: 0.6667
# Epoch 9/80
# 4708/4708 [==============================] - 0s 87us/step - loss: 46.6314 - acc: 0.7031
# Epoch 10/80
# 4708/4708 [==============================] - 0s 70us/step - loss: 41.1861 - acc: 0.7171
# Epoch 11/80
# 4708/4708 [==============================] - 0s 75us/step - loss: 40.3428 - acc: 0.7360 0s - loss: 40.5969 - acc: 0.73
# Epoch 12/80
# 4708/4708 [==============================] - 0s 75us/step - loss: 35.3154 - acc: 0.7513
# Epoch 13/80
# 4708/4708 [==============================] - 0s 69us/step - loss: 32.8696 - acc: 0.7610
# Epoch 14/80
# 4708/4708 [==============================] - 0s 70us/step - loss: 31.2837 - acc: 0.7749
# Epoch 15/80
# 4708/4708 [==============================] - 0s 74us/step - loss: 29.8787 - acc: 0.7833
# Epoch 16/80
# 4708/4708 [==============================] - 0s 67us/step - loss: 29.6054 - acc: 0.7910
# Epoch 17/80
# 4708/4708 [==============================] - 0s 69us/step - loss: 27.8588 - acc: 0.8003
# Epoch 18/80
# 4708/4708 [==============================] - 0s 66us/step - loss: 26.4610 - acc: 0.7942
# Epoch 19/80
# 4708/4708 [==============================] - 0s 67us/step - loss: 24.0041 - acc: 0.8150
# Epoch 20/80
# 4708/4708 [==============================] - 0s 93us/step - loss: 23.1335 - acc: 0.8067
# Epoch 21/80
# 4708/4708 [==============================] - 0s 71us/step - loss: 22.1485 - acc: 0.8214
# Epoch 22/80
# 4708/4708 [==============================] - 0s 85us/step - loss: 20.1205 - acc: 0.8290
# Epoch 23/80
# 4708/4708 [==============================] - 0s 69us/step - loss: 19.6431 - acc: 0.8377
# Epoch 24/80
# 4708/4708 [==============================] - 0s 70us/step - loss:
# Epoch 65/80
# 4708/4708 [==============================] - 0s 95us/step - loss: 6.0084 - acc: 0.9405
# Epoch 66/80
# 4708/4708 [==============================] - 0s 76us/step - loss: 4.9719 - acc: 0.9437
# Epoch 67/80
# 4708/4708 [==============================] - 0s 92us/step - loss: 6.1386 - acc: 0.9365
# Epoch 68/80
# 4708/4708 [==============================] - 0s 75us/step - loss: 4.6462 - acc: 0.9480
# Epoch 69/80
# 4708/4708 [==============================] - 0s 89us/step - loss: 5.0245 - acc: 0.9431
# Epoch 70/80
# 4708/4708 [==============================] - 0s 79us/step - loss: 6.0095 - acc: 0.9477
# Epoch 71/80
# 4708/4708 [==============================] - 0s 85us/step - loss: 5.0129 - acc: 0.9441
# Epoch 72/80
# 4708/4708 [==============================] - 0s 76us/step - loss: 4.8947 - acc: 0.9507
# Epoch 73/80
# 4708/4708 [==============================] - 0s 92us/step - loss: 4.4672 - acc: 0.9471
# Epoch 74/80
# 4708/4708 [==============================] - 0s 81us/step - loss: 6.0657 - acc: 0.9373
# Epoch 75/80
# 4708/4708 [==============================] - 0s 74us/step - loss: 4.7586 - acc: 0.9507
# Epoch 76/80
# 4708/4708 [==============================] - 0s 87us/step - loss: 4.8964 - acc: 0.9477
# Epoch 77/80
# 4708/4708 [==============================] - 0s 80us/step - loss: 5.1445 - acc: 0.9497
# Epoch 78/80
# 4708/4708 [==============================] - 0s 83us/step - loss: 6.0721 - acc: 0.9397
# Epoch 79/80
# 4708/4708 [==============================] - 0s 69us/step - loss: 4.6121 - acc: 0.9501
# Epoch 80/80
# 4708/4708 [==============================] - 0s 76us/step - loss: 5.5522 - acc: 0.9516
# 3140/3140 [==============================] - 0s 135us/step
# [426.36939514548914, 0.9592356687898089]

# %%
home = pd.read_csv('nba.games.stats - nba_2018.csv',usecols=['Team'])
away = pd.read_csv('nba.games.stats - nba_2018.csv',usecols=['Opponent']).values
ha = pd.read_csv('nba.games.stats - nba_2018.csv',usecols=['Home']).values
home = encoder.fit_transform(home)
away = encoder.fit_transform(away)
homeaway = encoder.fit_transform(ha)

# %%
new = np.append(home,away,axis=1)
new2 = pd.read_csv('nba.games.stats - nba_2018.csv',usecols=['FieldGoals','FieldGoalsAttempted','FieldGoals.','X3PointShots','X3PointShotsAttempted','X3PointShots.','FreeThrows','FreeThrowsAttempted','FreeThrows.','OffRebounds','TotalRebounds','Assists','Steals','Blocks','Turnovers','TotalFouls',
                        'Opp.FieldGoals', 'Opp.3PointShotsAttempted', 'Opp.3PointShots.', 'Opp.FreeThrows', 
                        'Opp.FreeThrowsAttempted', 'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds', 
                        'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers', 'Opp.TotalFouls',
                        'Opp.FieldGoalsAttempted', 'Opp.FieldGoals.', 'Opp.3PointShots']).values




new3 = np.append(new,homeaway,axis=1)
new2 = np.append(new3,new2,axis=1)
winLoss =  pd.read_csv('nba.games.stats - nba_2018.csv',usecols=['WINorLOSS']).values
winLoss = encoder.fit_transform(winLoss)
points = pd.read_csv('nba.games.stats - nba_2018.csv',usecols=['TeamPoints','OpponentPoints']).values
points = np.append(points,winLoss,axis=1)
# points.shape
# points = winLoss
# X_train, X_test, y_train, y_test = train_test_split(new2, points, test_size=0.40)
scores = model.evaluate(new2,points)
model.summary()
# print(scores)
# Out:
# 1958/1958 [==============================] - 0s 46us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_53 (Dense)             (None, 30)                2820
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_54 (Dense)             (None, 25)                775
# _________________________________________________________________
# dense_55 (Dense)             (None, 10)                260
# _________________________________________________________________
# dense_56 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 3,888
# Trainable params: 3,888
# Non-trainable params: 0
# _________________________________________________________________

# %%
predict = np.asarray([new2[5]])
hello = model.predict(predict)
print(hello[0][0], "-",hello[0][1])
# Out:
# 94.05093 - 61.953926
